# %% [markdown]
# ### pandas 시각화
# * https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# 한글폰트 사용시 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame()

# %% [markdown]
# ## plot; pandas 내장 플롯
# ### kind : str
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
#     - 'kde' : Kernel Density Estimation plot
#     - 'density' : same as 'kde'
#     - 'area' : area plot
#     - 'pie' : pie plot
#     - 'scatter' : scatter plot
#     - 'hexbin' : hexbin plot

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2000', periods=1000))
# time series로 데이터를 랜덤 생성

# %%
ts.plot()

# %%
# 누적합
ts = ts.cumsum()

# %%
ts.plot()

# %%
# 데이터프레임으로 플롯 그리기
df = pd.DataFrame(np.random.randn(1000, 4),
                  index=ts.index, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2000-01-01  1.768822 -0.831529  0.194317 -0.045793
# 2000-01-02 -0.114159 -1.439555  0.526582 -0.077384
# 2000-01-03  0.490899 -1.857679 -0.104482  1.289251
# 2000-01-04 -1.374029 -0.851486 -1.201480 -0.606020
# 2000-01-05  0.415898 -1.302560 -1.211096  0.971569
# 2000-01-06 -0.179999 -1.254995 -0.110033 -0.838259
# 2000-01-07  0.635856  0.976062 -0.247195 -0.787406
# 2000-01-08 -1.065711  0.060720 -0.865568  1.555757
# 2000-01-09 -1.628217  0.404983 -0.772144  0.240102
# 2000-01-10 -0.282461 -1.618816 -1.083580 -2.269048
# 2000-01-11 -0.552266 -0.892758  0.471019 -0.304094
# 2000-01-12 -0.031125  0.391137  0.994429 -0.889835
# 2000-01-13  0.021438  0.823231 -0.164443  0.987049
# 2000-01-14  0.968699  0.579407 -0.872800 -0.306023
# 2000-01-15  1.159738  0.389546  0.201839  0.182462
# 2000-01-16  0.334048 -1.039076 -0.101633  0.460071
# 2000-01-17  0.540387  1.809855  0.294423 -0.677406
# 2000-01-18 -2.895059  0.066901 -0.346433 -0.532455
# 2000-01-19 -0.758309 -0.212865 -0.107976  0.205960
# 2000-01-20 -2.060055 -1.141183 -0.522813  2.016780
# 2000-01-21 -1.139418  0.229768  2.002154  0.331365
# 2000-01-22  2.336380  0.718892 -0.666323 -0.492282
# 2000-01-23  0.576207  0.837800 -1.726767  0.450508
# 2000-01-24  0.076693 -0.802410  0.023834  0.250306
# 2000-01-25  2.107896 -0.877358  0.002298 -1.871666
# 2000-01-26  0.319636 -0.075944  0.064556 -1.969916
# 2000-01-27  0.308754 -0.274830  1.500625 -0.407169
# 2000-01-28 -0.264619  1.306454 -0.555576 -0.100253
# 2000-01-29  0.235941 -0.540221  0.341386 -0.501017
# 2000-01-30 -0.281760  0.808148  0.741552 -1.135361
# ...              ...       ...       ...       ...
# 2002-08-28  0.675866 -0.283879  0.509923 -0.097504
# 2002-08-29 -0.394238 -1.098268 -0.356635 -0.622765
# 2002-08-30  0.991853  0.441412 -0.277982  0.932006
# 2002-08-31  0.303557 -0.013752  0.930853 -0.163439
# 2002-09-01 -0.913888 -0.818082  0.427865 -0.829924
# 2002-09-02 -0.712447  1.437835 -0.944475 -1.031133
# 2002-09-03  0.373153 -0.907201 -1.131227 -0.479472
# 2002-09-04 -0.472708  0.720552 -1.885121 -1.014120
# 2002-09-05 -0.274791  0.029813 -0.983337  0.961505
# 2002-09-06  3.059126  0.634159  1.733940 -1.171100
# 2002-09-07 -1.736477 -0.909117  0.901775  1.881622
# 2002-09-08 -0.334565 -0.503158 -0.296173  0.826484
# 2002-09-09  3.644585 -0.707890  0.778710 -1.359498
# 2002-09-10  0.259468  1.257186  0.267849 -0.119137
# 2002-09-11  0.716468 -0.629971 -0.466578 -0.786169
# 2002-09-12 -0.286592  1.076947  1.429839  0.254240
# 2002-09-13 -0.427516  2.201112 -1.767657  0.689426
# 2002-09-14 -0.872315  0.090626 -0.359892  0.760023
# 2002-09-15  0.134989 -1.036789 -1.648382  0.682282
# 2002-09-16 -0.271153  1.037713  0.022336 -0.758056
# 2002-09-17  0.191592  0.763533  0.458650  1.438239
# 2002-09-18  0.173509 -0.636929  0.066930  0.395000
# 2002-09-19 -0.867663  1.484229  0.450886  0.858540
# 2002-09-20  0.597785  1.534667 -1.226890 -1.559067
# 2002-09-21 -0.541672  1.056289  0.738659 -0.643927
# 2002-09-22  0.502135  1.290957  0.956922  0.304380
# 2002-09-23  1.139001  0.248034  1.124551 -1.178517
# 2002-09-24 -0.154176  1.081083  0.952287 -0.109935
# 2002-09-25 -0.418385  2.174234  0.097219  0.074690
# 2002-09-26  0.222804  1.014896  0.348964 -1.705246
#
# [1000 rows x 4 columns]

# %%
df.plot()

# %%
# 누적합 구하기
df = df.cumsum()

# %%
df.plot()

# %%
# 데이터프레임 생성 및 누적합 구하기
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()

# %%
df3.head()
# Out:
#           B         C
# 0  0.325726  1.274220
# 1  0.969348  0.955475
# 2 -0.807245  1.698338
# 3 -1.615237  2.127335
# 4 -1.672784  3.021020

# %%
#A컬럼의 값을 시리즈 형태로 생성
df3['A'] = pd.Series(list(range(len(df))))

# %%
df3.head()
# Out:
#           B         C  A
# 0  0.325726  1.274220  0
# 1  0.969348  0.955475  1
# 2 -0.807245  1.698338  2
# 3 -1.615237  2.127335  3
# 4 -1.672784  3.021020  4

# %%
df3.plot(x='A', y='B')
